# %% [markdown]
# # 05 — Evaluation & Benchmarking
#
# Compare all models on RMSE, MAE, Directional Accuracy, Sharpe Ratio, and regime-wise performance.

# %%
import numpy as np
import pandas as pd
from sklearn.metrics import mean_squared_error, mean_absolute_error

# TODO: load model predictions and compute metrics
# metrics: RMSE, MAE, Directional Accuracy, Sharpe Ratio, Max Drawdown
