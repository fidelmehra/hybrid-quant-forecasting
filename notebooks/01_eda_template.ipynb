# %% [markdown]
# # 01 - Exploratory Data Analysis
#
# This notebook covers:
# - Loading raw OHLCV data
# - Visualising price and volume
# - Computing returns and log-returns
# - Rolling statistics
# - ACF/PACF plots
# - Regime identification (visual)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import yfinance as yf

# TODO: load data and run EDA
