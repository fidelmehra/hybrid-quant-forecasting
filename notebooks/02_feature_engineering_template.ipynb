# %% [markdown]
# # 02 - Feature Engineering
#
# This notebook covers:
# - Lag features
# - Rolling statistics
# - Technical indicators (RSI, MACD, Bollinger Bands)
# - Exogenous features (macro, sentiment)
# - Feature selection and importance

# %%
import pandas as pd
import numpy as np

# TODO: feature engineering pipeline
